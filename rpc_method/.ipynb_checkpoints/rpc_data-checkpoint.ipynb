# %%
from bitcoinrpc.authproxy import AuthServiceProxy
import pandas as pd

# %%
input_df = pd.read_csv('addresses.csv', index_col=0)
input_df.head()
# Out:
#                                             0
# 0          3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja
# 1          3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR
# 2  bc1q0xur68lq587lw8aqf96f4qqcmum6sqcpyyy94a
# 3          3JjtnDXknvY7HWidn5wt5BdZsRdXCGEt8y
# 4          3J9rQSzvNThPdN5FDbJAD3N8Wdce1KF6Ms

# %%
btc_hashes = input_df['0'].values
btc_hashes[:3]
# Out:
# array(['3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja',
#        '3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR',
#        'bc1q0xur68lq587lw8aqf96f4qqcmum6sqcpyyy94a'], dtype=object)

# %%
len(btc_hashes)
# Out:
# 899

# %% [markdown]
# #### In BTC Node, I have already imported these addreeses under 'test' label to watch only addresses and rescanned the wallet for all the transactions.

# %%
rpc_connection = AuthServiceProxy("http://%s:%s@ec2-3-81-20-12.compute-1.amazonaws.com:8332"%("test", "test"))

# %%
rpc_connection.getwalletinfo()
# Out:
# {'walletname': '',
#  'walletversion': 169900,
#  'balance': Decimal('0E-8'),
#  'unconfirmed_balance': Decimal('0E-8'),
#  'immature_balance': Decimal('0E-8'),
#  'txcount': 546,
#  'keypoololdest': 1619188148,
#  'keypoolsize': 1000,
#  'hdseedid': '4e1e1755f5b341841bc492f4d5991de26c8fb882',
#  'keypoolsize_hd_internal': 1000,
#  'paytxfee': Decimal('0E-8'),
#  'private_keys_enabled': True,
#  'avoid_reuse': False,
#  'scanning': {'duration': 2871, 'progress': Decimal('0.520940148967959')}}

# %%
rpc_connection.getblockchaininfo()
# Out:
# {'chain': 'main',
#  'blocks': 682279,
#  'headers': 682279,
#  'bestblockhash': '0000000000000000000a21882cf3405299b96d2245562dc86ef2e846d137dac9',
#  'difficulty': Decimal('20608845737768.16'),
#  'mediantime': 1620335388,
#  'verificationprogress': Decimal('0.9999996797512734'),
#  'initialblockdownload': False,
#  'chainwork': '00000000000000000000000000000000000000001d05957cd0561e8a927d9aa0',
#  'size_on_disk': 389905229722,
#  'pruned': False,
#  'softforks': {'bip34': {'type': 'buried', 'active': True, 'height': 227931},
#   'bip66': {'type': 'buried', 'active': True, 'height': 363725},
#   'bip65': {'type': 'buried', 'active': True, 'height': 388381},
#   'csv': {'type': 'buried', 'active': True, 'height': 419328},
#   'segwit': {'type': 'buried', 'active': True, 'height': 481824}},
#  'warnings': ''}

# %%
get_txs = rpc_connection.listtransactions('*', 100, 0) # change 'test' to '*' to include send tx as well
len(get_txs)
# Out:
# 0

# %%
labeled_addr = rpc_connection.getaddressesbylabel("test")
len(labeled_addr)
# Out:
# 899

# %%
df = pd.DataFrame()
count_val = 1000
skip_val = 0
while(True):
    get_txs = rpc_connection.listtransactions("*", count_val, skip_val, True) # change 'test' to '*' to include send tx as well
    if get_txs == []:
        break
    df = df.append(pd.DataFrame(get_txs), ignore_index=True)
    print(f"fetched {len(df)} txs")
    skip_val+=count_val

df
# Out:
# fetched 717 txs
#      involvesWatchonly                                     address category  \
# 0                 True          3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja  receive
# 1                 True          3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR  receive
# 2                 True          3QhHo5Y2odxP6ysLya5YvUQZMxyFDxyYjL     send
# 3                 True          3JjtnDXknvY7HWidn5wt5BdZsRdXCGEt8y  receive
# 4                 True          32RLGxLjwEvcaT7r3afgZQskYfZ9bqxHHm     send
# ..                 ...                                         ...      ...
# 712               True  bc1qa92ggx8gmaz9zg62wqz2kqdhl5qqxpv6ggtmvj  receive
# 713               True  bc1q5et0duz9jkl56lwsl6gq5nxuu5dskunwzexd6r  receive
# 714               True  bc1q5et0duz9jkl56lwsl6gq5nxuu5dskunwzexd6r  receive
# 715               True  bc1q5et0duz9jkl56lwsl6gq5nxuu5dskunwzexd6r  receive
# 716               True  bc1q5et0duz9jkl56lwsl6gq5nxuu5dskunwzexd6r  receive
#
#            amount label  vout  confirmations  \
# 0     50.00000000  test     0          64756
# 1     50.00000000  test     1          64756
# 2    -99.99992736   NaN     0          64745
# 3     10.00000000  test     0          63135
# 4     -9.99997840   NaN     0          62087
# ..            ...   ...   ...            ...
# 712    0.00091862  test     0            477
# 713    1.00000000  test     0            320
# 714    0.06207628  test     1            314
# 715    0.17756380  test     0            312
# 716    0.03341474  test    38            171
#
#                                              blockhash  blockheight  \
# 0    0000000000000000000a1c5c75de52f3fda0b444b2d956...       617518
# 1    0000000000000000000a1c5c75de52f3fda0b444b2d956...       617518
# 2    00000000000000000005613da8ffa2191bf7b851446079...       617529
# 3    000000000000000000116e16b59bcc11133e158d28ad95...       619139
# 4    0000000000000000000d13e44844b56e399746719d415e...       620187
# ..                                                 ...          ...
# 712  0000000000000000000160a86ec0d39b793ef8395b0ba5...       681797
# 713  0000000000000000000b3b83e51a779ec9adcfcf3a7f82...       681954
# 714  00000000000000000004bfd7ebbb74b876aa8e488dc07a...       681960
# 715  000000000000000000065b0ebdb599864c1f7ecba417c4...       681962
# 716  000000000000000000071c86a6c64d3f269f992e3048fe...       682103
#
#      blockindex   blocktime  \
# 0           872  1581789478
# 1          1082  1581789478
# 2            36  1581792148
# 3           521  1582764816
# 4          2961  1583348600
# ..          ...         ...
# 712         543  1620086827
# 713         311  1620163929
# 714         313  1620165254
# 715         768  1620166483
# 716        1799  1620242211
#
#                                                   txid walletconflicts  \
# 0    0206a1c8723c7a0ef894354da3a4cdfa9787541c759a18...              []
# 1    784b529b29b054e15637ec0ceb7dcc56e34f0737ccb9f7...              []
# 2    f9aaddbc3a7fd1079e4418dc2b0a8be76caa42c4127819...              []
# 3    96783e3b6e405410a4c1677dc98b09836abafccbfe33e1...              []
# 4    54f55be92d7424880981bb25c01992b6bbff13da1e47a0...              []
# ..                                                 ...             ...
# 712  bfd563ccb04b451695f218490b7de7987bc86634bf49e6...              []
# 713  fcc7359648d8ffb5498e2f0ea345d13d1d74c635a2f248...              []
# 714  207a0f8dbd59f8337633b7f7a42a5837e713226c8cb40e...              []
# 715  85f5180782b0d42cacf4ba0e7e31bc1aeba52477f93479...              []
# 716  7d1c33a944bd0dd2b30a03ac7b33322c2b74f51ea74633...              []
#
#            time  timereceived bip125-replaceable          fee abandoned
# 0    1581789478    1619660717                 no          NaN       NaN
# 1    1581789478    1619660717                 no          NaN       NaN
# 2    1581792148    1619660717                 no  -0.00007264     False
# 3    1582764816    1619660755                 no          NaN       NaN
# 4    1583348600    1619660780                 no  -0.00002160     False
# ..          ...           ...                ...          ...       ...
# 712  1620086363    1620086363                 no          NaN       NaN
# 713  1620163843    1620163843                 no          NaN       NaN
# 714  1620165142    1620165142                 no          NaN       NaN
# 715  1620165447    1620165447                 no          NaN       NaN
# 716  1620231562    1620231562                 no          NaN       NaN
#
# [717 rows x 18 columns]

# %%
df_by_addr = df.groupby('address')
len(df_by_addr)
# Out:
# 340

# %%
for _, gp in df_by_addr:
#     if gp['address'].values[0] == '13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W':
#         print(gp)
    print(len(gp), gp['address'].values[0])
#     break
# Out:
#      involvesWatchonly                             address category  \
# 142               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 144               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 154               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 165               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 178               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 179               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 180               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 187               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 201               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 206               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 207               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 215               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 221               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 223               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 224               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 227               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 229               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 232               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 382               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
# 672               True  13qF2huSpD4Vim62ChBFbUjtxWQ1zSCE4W  receive
#
#          amount label  vout  confirmations  \
# 142  8.76528974  test     5          38391
# 144  1.35536830  test     0          38090
# 154  0.02089639  test    16          37852
# 165  0.01752469  test    15          36690
# 178  0.03763931  test     1          35650
# 179  0.15064033  test     4          35645
# 180  0.09573268  test     7          35511
# 187  0.09842232  test    10          34967
# 201  0.04511533  test    12          33332
# 206  0.04687649  test    23          32828
# 207  0.01214284  test     6          32741
# 215  0.08417866  test     1          31696
# 221  0.09236950  test    10          30869
# 223  0.02997640  test    16          30729
# 224  0.01385163  test   239          30687
# 227  0.00147061  test    33          30314
# 229  0.09052988  test     0          29348
# 232  0.10269011  test     0          29206
# 382  0.05430342  test     1          21701
# 672  8.99960270  test     1           5028
#
#                                              blockhash  blockheight  \
# 142  0000000000000000000d4aacf983a2cf4d64abb3b1ff59...       643883
# 144  00000000000000000003e4f14676347e82158f367a6657...       644184
# 154  00000000000000000007797d05068c1e71941a1ef573a0...       644422
# 165  00000000000000000006ef419c84abb218b5bc3f18c2da...       645584
# 178  0000000000000000000bc758a22cebf45ee1abbae1edaf...       646624
# 179  00000000000000000002a55490dcd6dc33a802134d3827...       646629
# 180  00000000000000000000d8392d020f70fd080bc4b5003e...       646763
# 187  000000000000000000053466af51edabf0667048f6cf52...       647307
# 201  00000000000000000004982e9a1080f40e7ab657136683...       648942
# 206  00000000000000000002ba770aefabecf836239b8e7352...       649446
# 207  0000000000000000000a56a7be2a0e8c5b7382c342fe3a...       649533
# 215  0000000000000000000bf9515e3f77e1446b266a557443...       650578
# 221  0000000000000000000b3f6c30ead8b080d3b062f4e7b3...       651405
# 223  00000000000000000009d60744117fca1540db14c9a930...       651545
# 224  000000000000000000067b0b95d5c82662d5cca712006b...       651587
# 227  00000000000000000002234390b78e3784a1639aed4115...       651960
# 229  0000000000000000000dc78cd484ad8ffef08be45782ab...       652926
# 232  0000000000000000000ae95e2dfc1c9313645b63b43e82...       653068
# 382  0000000000000000000217854bdbaad037661fa56e7cc0...       660573
# 672  0000000000000000000b9451aef5bd52deb69da0f35b03...       677246
#
#      blockindex   blocktime  \
# 142         651  1597517644
# 144        1783  1597696771
# 154        1600  1597857886
# 165        3153  1598558033
# 178        2310  1599174521
# 179        1504  1599179168
# 180         805  1599264508
# 187         560  1599571091
# 201        1465  1600446886
# 206         874  1600744725
# 207        1445  1600802014
# 215         755  1601426995
# 221         647  1601923766
# 223         569  1602006938
# 224        1769  1602039351
# 227        1515  1602249434
# 229        1678  1602808614
# 232        1981  1602889021
# 382        1438  1607483906
# 672        1167  1617248628
#
#                                                   txid walletconflicts  \
# 142  df8578849c984047878841a499645a99bd0d5367fe9ef6...              []
# 144  bfe45648e7d435939305d0f28a4732f26a2116a81b5cb1...              []
# 154  0d581c33928ebf0bea12d300592496821fb3a18240ceba...              []
# 165  597b94e1d80695d6daf5146e629c5c41afb70414740f46...              []
# 178  2211c7b6cdfdde553a7c66e3af153c632e822f4e10932a...              []
# 179  2e697399a1387b7af6e72243f0f1d4da5744dfe19ff17b...              []
# 180  2467e7da1f85d944b0ebae176aff30e854cc22dee13455...              []
# 187  ff763d2addeaba79c4110536cdce66291a940cb3f0cc63...              []
# 201  c3429063c9037fe660eedd154e87a923f625b2e0124cc4...              []
# 206  e1d2e07f0f9f81e4ebde076952b1112f90429390aff3ae...              []
# 207  5cb3bc76868214d68cc1b6b21034b6af9165a7c72b0d61...              []
# 215  a4d844352b8b052d1be1303a24a76d7de17d4bdd9e449e...              []
# 221  da71a7b348992d337dc250c2e544f393184d0f7a76d95c...              []
# 223  ebfd7769199e70939a3ac2d05098d11d821df47a9bb4c1...              []
# 224  77901f4aa6ed74c2028ada48ca6526420e7fb4c1d9ae18...              []
# 227  653008b6a8954385172a65f579de5b8f2b18477bb7b972...              []
# 229  b7ef8ca40167fcedeac788b4974497d23649357065612d...              []
# 232  bbe75b4720c312c08ac9af41a43360b65089e29c2915ae...              []
# 382  7679dd67100efcf2fa4861171a5f914de70b90e2d8fe47...              []
# 672  d33db9df64d093250126fb1c2e65c8b2a0c4e9b8700642...              []
#
#            time  timereceived bip125-replaceable  fee abandoned
# 142  1597517644    1619661406                 no  NaN       NaN
# 144  1597696771    1619661415                 no  NaN       NaN
# 154  1597857886    1619661422                 no  NaN       NaN
# 165  1598558033    1619661457                 no  NaN       NaN
# 178  1599174521    1619661487                 no  NaN       NaN
# 179  1599179168    1619661487                 no  NaN       NaN
# 180  1599264508    1619661491                 no  NaN       NaN
# 187  1599571091    1619661508                 no  NaN       NaN
# 201  1600446886    1619661552                 no  NaN       NaN
# 206  1600744725    1619661566                 no  NaN       NaN
# 207  1600802014    1619661568                 no  NaN       NaN
# 215  1601426995    1619661598                 no  NaN       NaN
# 221  1601923766    1619661624                 no  NaN       NaN
# 223  1602006938    1619661629                 no  NaN       NaN
# 224  1602039351    1619661630                 no  NaN       NaN
# 227  1602249434    1619661644                 no  NaN       NaN
# 229  1602808614    1619661675                 no  NaN       NaN
# 232  1602889021    1619661679                 no  NaN       NaN
# 382  1607483906    1619661912                 no  NaN       NaN
# 672  1617248628    1619662420                 no  NaN       NaN

# %%
txids = df.txid.values
tx_df = pd.DataFrame()
total_txs = len(txids)
i = 0
for txid in txids[:10]:
    raw_data = rpc_connection.gettransaction(txid, False, True)
    vout_addr = [", ".join(raw_data['decoded']['vout'][i]['scriptPubKey']['addresses']) for i in range (len(raw_data['decoded']['vout']))]
    vin_addr = [(raw_data['decoded']['vin'][i]['txid'], raw_data['decoded']['vin'][i]['vout']) for i in range(len(raw_data['decoded']['vin']))]
    line = [[raw_data['decoded']['txid'],vin_addr, vout_addr]]
    temp_df = pd.DataFrame(line, columns=['txid','vin_raw_list','vout_list'])
    tx_df = tx_df.append(temp_df, ignore_index = True)
    i+=1
    print(f"progress {i}/{total_txs} txs")
# Out:
# progress 1/717 txs
# progress 2/717 txs
# progress 3/717 txs
# progress 4/717 txs
# progress 5/717 txs
# progress 6/717 txs
# progress 7/717 txs
# progress 8/717 txs
# progress 9/717 txs
# progress 10/717 txs

# %%
merged_df = pd.merge(df, tx_df)
merged_df
# Out:
#     involvesWatchonly                             address category  \
# 0                True  3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja  receive
# 1                True  3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR  receive
# 2                True  3QhHo5Y2odxP6ysLya5YvUQZMxyFDxyYjL     send
# 3                True  3JjtnDXknvY7HWidn5wt5BdZsRdXCGEt8y  receive
# 4                True  32RLGxLjwEvcaT7r3afgZQskYfZ9bqxHHm     send
# 5                True  336Cqh6hp7qXtJtU26BAPFWW1v2bBymrej  receive
# 6                True  3J9rQSzvNThPdN5FDbJAD3N8Wdce1KF6Ms  receive
# 7                True  3J9rQSzvNThPdN5FDbJAD3N8Wdce1KF6Ms  receive
# 8                True  3B5BKg2oYxnLw274V1Eg2sVB9tUdmQyTxd     send
# 9                True  3B5BKg2oYxnLw274V1Eg2sVB9tUdmQyTxd     send
# 10               True  3DzNH41tkWt3YYbwkWYLUi8fD7Rj6WJrnX     send
# 11               True  3DzNH41tkWt3YYbwkWYLUi8fD7Rj6WJrnX     send
#
#            amount label  vout  confirmations  \
# 0     50.00000000  test     0          64611
# 1     50.00000000  test     1          64611
# 2    -99.99992736   NaN     0          64600
# 3     10.00000000  test     0          62990
# 4     -9.99997840   NaN     0          61942
# 5      0.00060000  test    69          61941
# 6      0.01000000  test     0          61846
# 7    249.99000000  test     0          61726
# 8   -250.00000000   NaN     1          61625
# 9   -250.00000000   NaN     1          61625
# 10    -0.00051927   NaN     0          61625
# 11    -0.00051927   NaN     0          61625
#
#                                             blockhash  blockheight  \
# 0   0000000000000000000a1c5c75de52f3fda0b444b2d956...       617518
# 1   0000000000000000000a1c5c75de52f3fda0b444b2d956...       617518
# 2   00000000000000000005613da8ffa2191bf7b851446079...       617529
# 3   000000000000000000116e16b59bcc11133e158d28ad95...       619139
# 4   0000000000000000000d13e44844b56e399746719d415e...       620187
# 5   00000000000000000008279e870537b797c1b4882d8aee...       620188
# 6   000000000000000000059238b239d4266b1eb4e07ee438...       620283
# 7   0000000000000000000084357f7d461b6b735b5621a97a...       620403
# 8   0000000000000000000099ab0934cab01fec254af919c5...       620504
# 9   0000000000000000000099ab0934cab01fec254af919c5...       620504
# 10  0000000000000000000099ab0934cab01fec254af919c5...       620504
# 11  0000000000000000000099ab0934cab01fec254af919c5...       620504
#
#     blockindex   blocktime                                               txid  \
# 0          872  1581789478  0206a1c8723c7a0ef894354da3a4cdfa9787541c759a18...
# 1         1082  1581789478  784b529b29b054e15637ec0ceb7dcc56e34f0737ccb9f7...
# 2           36  1581792148  f9aaddbc3a7fd1079e4418dc2b0a8be76caa42c4127819...
# 3          521  1582764816  96783e3b6e405410a4c1677dc98b09836abafccbfe33e1...
# 4         2961  1583348600  54f55be92d7424880981bb25c01992b6bbff13da1e47a0...
# 5           47  1583349315  a9b6dd0615a58a1a1d34e98a326fbe299ecb0cd48cb008...
# 6          999  1583389171  d5be29d705014b9d0e79560b8db92934a9da31ed18d0c9...
# 7          590  1583458301  bf1df158247cba3df3407f7593d3c3e9706ebed4fd721c...
# 8         1746  1583519656  6e34edc5a5b63aedd3547bf08448cd2701ba6b1ab92354...
# 9         1746  1583519656  6e34edc5a5b63aedd3547bf08448cd2701ba6b1ab92354...
# 10        1746  1583519656  6e34edc5a5b63aedd3547bf08448cd2701ba6b1ab92354...
# 11        1746  1583519656  6e34edc5a5b63aedd3547bf08448cd2701ba6b1ab92354...
#
#    walletconflicts        time  timereceived bip125-replaceable          fee  \
# 0               []  1581789478    1619660717                 no          NaN
# 1               []  1581789478    1619660717                 no          NaN
# 2               []  1581792148    1619660717                 no  -0.00007264
# 3               []  1582764816    1619660755                 no          NaN
# 4               []  1583348600    1619660780                 no  -0.00002160
# 5               []  1583349315    1619660780                 no          NaN
# 6               []  1583389171    1619660782                 no          NaN
# 7               []  1583458301    1619660786                 no          NaN
# 8               []  1583519656    1619660788                 no  -0.00008073
# 9               []  1583519656    1619660788                 no  -0.00008073
# 10              []  1583519656    1619660788                 no  -0.00008073
# 11              []  1583519656    1619660788                 no  -0.00008073
#
#    abandoned                                       vin_raw_list  \
# 0        NaN  [(08e74e84b2545e1c3056718b962827038aa0dd097383...
# 1        NaN  [(6d9a3a3e0805940cf0f6380c3f9d85b18c24822f875b...
# 2      False  [(0206a1c8723c7a0ef894354da3a4cdfa9787541c759a...
# 3        NaN  [(2aa53732be0c221f78dd33a23f707fa70275573acc89...
# 4      False  [(96783e3b6e405410a4c1677dc98b09836abafccbfe33...
# 5        NaN  [(c246277722298f9634d75e7f6e95dc17c27a358fc4cc...
# 6        NaN  [(58e87bd6c6eb91bc83257578341f18eddd75882add0a...
# 7        NaN  [(94fcb26ade1d0ddaa06a0262718f8041537675705dd6...
# 8      False  [(a9b6dd0615a58a1a1d34e98a326fbe299ecb0cd48cb0...
# 9      False  [(a9b6dd0615a58a1a1d34e98a326fbe299ecb0cd48cb0...
# 10     False  [(a9b6dd0615a58a1a1d34e98a326fbe299ecb0cd48cb0...
# 11     False  [(a9b6dd0615a58a1a1d34e98a326fbe299ecb0cd48cb0...
#
#                                             vout_list
# 0                [3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja]
# 1   [3LxjWbVcEa8fsKQ913H3rDuzrZihFxd5Qx, 3JNZyt1oc...
# 2                [3QhHo5Y2odxP6ysLya5YvUQZMxyFDxyYjL]
# 3   [3JjtnDXknvY7HWidn5wt5BdZsRdXCGEt8y, 3BZ7nCQ7w...
# 4                [32RLGxLjwEvcaT7r3afgZQskYfZ9bqxHHm]
# 5   [bc1qs0pkt4j5e7e8xacd6839z37zcn5uzlexxwwwd8, 1...
# 6   [3J9rQSzvNThPdN5FDbJAD3N8Wdce1KF6Ms, 34ZUrLmLU...
# 7   [3J9rQSzvNThPdN5FDbJAD3N8Wdce1KF6Ms, 39s8d6pmy...
# 8   [3DzNH41tkWt3YYbwkWYLUi8fD7Rj6WJrnX, 3B5BKg2oY...
# 9   [3DzNH41tkWt3YYbwkWYLUi8fD7Rj6WJrnX, 3B5BKg2oY...
# 10  [3DzNH41tkWt3YYbwkWYLUi8fD7Rj6WJrnX, 3B5BKg2oY...
# 11  [3DzNH41tkWt3YYbwkWYLUi8fD7Rj6WJrnX, 3B5BKg2oY...

# %%
merged_df.to_csv('temp.csv')
