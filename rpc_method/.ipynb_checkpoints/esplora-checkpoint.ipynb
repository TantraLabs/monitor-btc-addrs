# %%
import pandas as pd
import requests
from collections import defaultdict
import time

input_df = pd.read_csv('addresses.csv', index_col=0)
input_df.head()
# Out:
#                                             0
# 0          3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja
# 1          3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR
# 2  bc1q0xur68lq587lw8aqf96f4qqcmum6sqcpyyy94a
# 3          3JjtnDXknvY7HWidn5wt5BdZsRdXCGEt8y
# 4          3J9rQSzvNThPdN5FDbJAD3N8Wdce1KF6Ms

# %%
btc_hashes = input_df['0'].values
addr_data = defaultdict(list)
i = 0
for btc_hash in btc_hashes[:10]: # limiting for testing
    last_tx = ''
    while(True):
        URL = "https://blockstream.info/api/address/{}/txs/chain"
        if last_tx != '':
            URL+=f'/{last_tx}'

        data = requests.get(URL.format(btc_hash))


        data = data.json()
        addr_data[btc_hash].extend(data)
        if (len(data) < 25):
            break
        last_tx = data[-1]['txid']
    i+=1
    if i % 20 == 0:
        print(f"{i}/{len(btc_hashes)}")
    # time.sleep(1)
print(f"{i}/{len(btc_hashes)}")
# Out:
# 10/899

# %%
history = pd.DataFrame()

for addr in addr_data.keys():
    for tx in addr_data[addr]:
        amount = 0
        for v_in in tx['vin']:
            if v_in['prevout']['scriptpubkey_address'] == addr:
                amount += v_in['prevout']['value']
        amount = -amount

        for v_out in tx['vout']:
            if v_out['scriptpubkey_address'] == addr:
                amount += v_out['value'] 
                
#         amount /= 1e8
        
        tx_history = {
            'time': tx['status']['block_time'],
            'addr': addr,
            'value': amount,
            'txid':tx['txid']
        }
        tx_df = pd.DataFrame(tx_history, index=[0])
        history = history.append(tx_df, ignore_index=True)
#     break

history
# Out:
#           time                                        addr        value  \
# 0   1589052010          3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja  -1310546000
# 1   1589050796          3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja   1310546000
# 2   1581792148          3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja  -5000000000
# 3   1581789478          3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja   5000000000
# 4   1589052010          3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR  -1310507782
# 5   1589050796          3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR   1310507782
# 6   1581792148          3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR  -5000000000
# 7   1581789478          3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR   5000000000
# 8   1619846554  bc1q0xur68lq587lw8aqf96f4qqcmum6sqcpyyy94a     99700000
# 9   1613500759  bc1q0xur68lq587lw8aqf96f4qqcmum6sqcpyyy94a  -1130169000
# 10  1613498557  bc1q0xur68lq587lw8aqf96f4qqcmum6sqcpyyy94a   1130069000
# 11  1613498557  bc1q0xur68lq587lw8aqf96f4qqcmum6sqcpyyy94a       100000
# ...

# %%
history.set_index('time', drop=True, inplace=True)
history = history.sort_index()
history['balance']  =  history.value.cumsum().div(1e8)

# %%
history
# Out:
#                                                   addr        value  \
# time
# 1581789478          3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja   5000000000
# 1581789478          3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR   5000000000
# 1581792148          3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja  -5000000000
# 1581792148          3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR  -5000000000
# 1582764816          3JjtnDXknvY7HWidn5wt5BdZsRdXCGEt8y   1000000000
# 1583348600          3JjtnDXknvY7HWidn5wt5BdZsRdXCGEt8y  -1000000000
# 1583349315          336Cqh6hp7qXtJtU26BAPFWW1v2bBymrej        60000
# 1583389171          3J9rQSzvNThPdN5FDbJAD3N8Wdce1KF6Ms      1000000
# 1583458301          3J9rQSzvNThPdN5FDbJAD3N8Wdce1KF6Ms  24999000000
# 1583519656          336Cqh6hp7qXtJtU26BAPFWW1v2bBymrej       -60000
# 1583519656          3J9rQSzvNThPdN5FDbJAD3N8Wdce1KF6Ms -25000000000
# 1583634090          336Cqh6hp7qXtJtU26BAPFWW1v2bBymrej   1199940000
# 1583786424          336Cqh6hp7qXtJtU26BAPFWW1v2bBymrej  -1199940000
# ...

# %%
# history_cumsum_balance = history.set_index('time').sort_index().groupby(['addr', 'time', 'txid']).sum().groupby(level=0).cumsum().reset_index().rename(columns = {'value':'balance'})
# history_balance = pd.merge(history, history_cumsum_balance, on = ['addr', 'time', 'txid'])
# history_balance

# %%
deposits = pd.DataFrame()
withdrawls = pd.DataFrame()
progress = 0

for addr in addr_data.keys(): # here the addr_data is same that was calculated before
    for tx in addr_data[addr]:
        for vin in tx['vin']:
            tx_in = {}

            tx_in['timestamp'] = tx['status']['block_time']
            tx_in['tx_hash']   = tx['txid']
            tx_in['amount']    = vin['prevout']['value'] # may put a minus sign in amount to show deposit
            tx_in['tx_type']   = 'deposit'
            tx_in['type']      = 'btc'
            tx_in['address']   = vin['prevout']['scriptpubkey_address']
            deposits = deposits.append(pd.DataFrame(tx_in,index=[0]))

        for vout in tx['vout']:
            tx_out = {}

            tx_out['timestamp'] = tx['status']['block_time']
            tx_out['tx_hash']   = tx['txid']
            tx_out['amount']    = vout['value']
            tx_out['tx_type']   = 'withdraw'
            tx_out['type']      = 'btc'
            tx_out['address']   = vout['scriptpubkey_address']
            withdrawls = withdrawls.append(pd.DataFrame(tx_in,index=[0]))

            

    progress+=1
    if (progress % 10 == 0):
        print(f"progress {progress}/{len(addr_data)} txs")        
print(f"progress {progress}/{len(addr_data)} txs")        
    

deposits = deposits.set_index('address')
deposits['address'] = deposits.index


withdrawls = withdrawls.set_index('address')
withdrawls['address'] = withdrawls.index
# Out:
# progress 10/10 txs
# progress 10/10 txs

# %%
deposits
# Out:
#                                              timestamp  \
# address
# 3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja          1589052010
# 3DzNH41tkWt3YYbwkWYLUi8fD7Rj6WJrnX          1589052010
# 3EWxsS8SBYKmYn3aPQ2uu84iehK8J5MGNW          1589052010
# 3HbWgReV2hgvrR6g7VhiWxcz6QY8aYwviK          1589052010
# 3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR          1589052010
# ...                                                ...
# bc1qndw3lp44etantehvgsvkdxunpcgqt0a2sjqgvy  1610582916
# bc1qnxdgcj0ywhh4a7j8u8hrzd0lhzlfquservd77r  1610582916
# bc1qnxdgcj0ywhh4a7j8u8hrzd0lhzlfquservd77r  1610582916
# bc1qpdnegdpanatyh4m3tty7kexeu9m3jc52ll6l8f  1610579449
# bc1qpdnegdpanatyh4m3tty7kexeu9m3jc52ll6l8f  1610579449
#
#                                                                                       tx_hash  \
# address
# 3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja          c5fc5cd22c553207714ac3fa6f51645d47be707b6d5122...
# 3DzNH41tkWt3YYbwkWYLUi8fD7Rj6WJrnX          c5fc5cd22c553207714ac3fa6f51645d47be707b6d5122...
# ...

# %%
withdrawls
# Out:
#                                              timestamp  \
# address
# 3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR          1589052010
# 3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR          1589052010
# 3BZUnQ456cR27eEKmJWz4u73brqtwEmscM          1589050796
# 3BZUnQ456cR27eEKmJWz4u73brqtwEmscM          1589050796
# 3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR          1581792148
# ...                                                ...
# bc1qnxdgcj0ywhh4a7j8u8hrzd0lhzlfquservd77r  1610582916
# bc1qpdnegdpanatyh4m3tty7kexeu9m3jc52ll6l8f  1610579449
# bc1qpdnegdpanatyh4m3tty7kexeu9m3jc52ll6l8f  1610579449
# bc1qpdnegdpanatyh4m3tty7kexeu9m3jc52ll6l8f  1610579449
# bc1qpdnegdpanatyh4m3tty7kexeu9m3jc52ll6l8f  1610579449
#
#                                                                                       tx_hash  \
# address
# 3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR          c5fc5cd22c553207714ac3fa6f51645d47be707b6d5122...
# 3JNZyt1ocETf9oHscQfx17XNqY3odHAjaR          c5fc5cd22c553207714ac3fa6f51645d47be707b6d5122...
# ...

# %%
addr_data['3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja']
# Out:
# [{'txid': 'c5fc5cd22c553207714ac3fa6f51645d47be707b6d51226daaae5b21e0832483',
#   'version': 1,
#   'locktime': 0,
#   'vin': [{'txid': '4a72fc833a5ab16ad45627a3aa499f4b1ab44363a88dda12dadd922cd47b24ed',
#     'vout': 1,
#     'prevout': {'scriptpubkey': 'a9147f950ba16e5f09cd3206514da708ff9df1eb9fba87',
#      'scriptpubkey_asm': 'OP_HASH160 OP_PUSHBYTES_20 7f950ba16e5f09cd3206514da708ff9df1eb9fba OP_EQUAL',
#      'scriptpubkey_type': 'p2sh',
#      'scriptpubkey_address': '3DKcHmHdqcUDAX2Yi2sjX9Hauam25Nk5Ja',
#      'value': 1310546000},
#     'scriptsig': '160014a1bb0dfc08d213176dbaf03072c60e90e5285c5e',
#     'scriptsig_asm': 'OP_PUSHBYTES_22 0014a1bb0dfc08d213176dbaf03072c60e90e5285c5e',
#     'witness': ['304402204803ea7b57f4e91776618cdc3787c932a0cf7b5d43125eb54dd35aec6ccfd80d022038c19200f3e6ac119ac5db1e56d15f7d161ab9646417ccd79d8f8baf6b9737fb01',
#      '02aec416909e617f1b798a491cf09f0feedd8efbfbbf3bc78fe00d9fa7bbc0778e'],
#     'is_coinbase': False,
# ...
